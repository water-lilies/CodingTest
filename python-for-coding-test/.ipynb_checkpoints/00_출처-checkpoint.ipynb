# %% [markdown]
# ## 이것이 코딩테스트다
# - 교재 구매 링크 : https://www.hanbit.co.kr/store/books/look.php?p_code=B8945183661 <br>
# - 유튜브 : https://www.youtube.com/playlist?list=PLVsNizTWUw7H9_of5YCB0FmsSc-K44y81
# - 깃허브 주소 : https://github.com/ndb796/python-for-coding-test
#
# 위 링크 밑 아래 교재를 참고하여 <br>
# 연습용으로 작성된 코드를 담고 있습니다.

# %% [markdown]
# ![image.png](attachment:image.png)
