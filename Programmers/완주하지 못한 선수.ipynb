# %% [markdown]
# ### 문제 설명
# 수많은 마라톤 선수들이 마라톤에 참여하였습니다. 단 한 명의 선수를 제외하고는 모든 선수가 마라톤을 완주하였습니다.
#
# 마라톤에 참여한 선수들의 이름이 담긴 배열 participant와 완주한 선수들의 이름이 담긴 배열 completion이 주어질 때, 완주하지 못한 선수의 이름을 return 하도록 solution 함수를 작성해주세요.

# %% [markdown]
# ### 제한사항
# - 마라톤 경기에 참여한 선수의 수는 1명 이상 100,000명 이하입니다.
# - completion의 길이는 participant의 길이보다 1 작습니다.
# - 참가자의 이름은 1개 이상 20개 이하의 알파벳 소문자로 이루어져 있습니다.
# - 참가자 중에는 동명이인이 있을 수 있습니다

# %%
import pandas as pd
import numpy as np

# %%
participant1 = ["leo", "kiki", "eden"]
completion1 = ["eden", "kiki"]

participant2 = ["marina", "josipa", "nikola", "vinko", "filipa"]
completion2 = ["josipa", "filipa", "marina", "nikola"]

participant3 = ["mislav", "stanko", "mislav", "ana"]
completion3 = ["stanko", "mislav", "ana"]

# %%
participant1[0]
# Out:
# 'leo'

# %%
for i in range(len(participant1)):
    print(i)
# Out:
# 0
# 1
# 2

# %%
if len(participant1) == len(set(participant1)):
    for i in range(len(participant1)):
        if participant1[i] not in completion1:
            print(participant1[i])
else:
    participant.remove(participant1[i])
# Out:
# leo

# %%
# 효율성 테스트에서 실패

for i in range(len(completion3)):
    participant3.remove(completion3[i])
print(participant3)
# Out:
# ['mislav']

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def solution(participant, completion):
    # 중복값이 없는 경우
    if len(participant) == len(set(participant)):
        for i in range(len(participant)):
            if participant[i] not in completion:
                print(participant[i])
    # 중복값이 있는 경우            
    else:
        print([i for i, j in zip(participant, completion) if i == j][0])

# %%
if len(participant3) == len(set(participant3)):
    for i in range(len(participant3)):
        if participant3[i] not in completion3:
            print(participant3[i])
else:
    print("".join([i for i, j in zip(participant3, completion3) if i == j]))
# Out:
# mislav

# %%
if len(participant1) == len(set(participant1)):
    for i in range(len(participant1)):
        if participant1[i] not in completion1:
            answer = participant1[i]
else:
    answer = [i for i, j in zip(participant1, completion1) if i == j][0]
    
print(answer)
# Out:
# leo

# %%
print(list(set(participant1) - set(completion1))[0])
# Out:
# leo

# %% [markdown]
# ### collections

# %%
import collections

def solution1(participant, completion):
    answer = collections.Counter(participant) - collections.Counter(completion)
    return list(answer.keys())[0]

# %%
solution(participant3, completion3)
# Out:
# 'mislav'

# %%
def solution2(participant, completion):
    participant.sort()
    completion.sort()
    for par, com in zip(participant,completion):
        if par != com:
            return par
    
    return participant[-1]

# %%
solution(participant3, completion3)
# Out:
# 'mislav'
